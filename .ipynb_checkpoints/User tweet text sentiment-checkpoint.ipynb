# %%
# -*- coding: utf-8 -*-

# %%
import csv
import re
import json
import os
import threading
from pprint import pprint as pp
from functools import reduce
import itertools as it

# %%
from pythainlp.sentiment import sentiment
from pythainlp.romanization import romanization
import pandas as pd
import numpy as np
import matplotlib

# %%
user_tweet_files = os.listdir('./user-tweet')
print('# of user file = %d' % len(user_tweet_files))
# Out:
# # of user file = 4672

# %%
party_name = ['ประชาธิปัตย์', 'พลังประชารัฐ', 'รวมพลังประชาชาติไทย', 'เสรีรวมไทย', 'เพื่อไทย', 'อนาคตใหม่']
user_sentiment_list = []

pro_party_account = {
    'ประชาธิปัตย์': set(), 
    'พลังประชารัฐ': set(), 
    'รวมพลังประชาชาติไทย': set(), 
    'เสรีรวมไทย': set(), 
    'เพื่อไทย': set(), 
    'อนาคตใหม่': set(),
}

# %%
def sentiment_thread(tweet_data, index):
    if index % 100 == 0:
        print('Now, the index is %d' % index)
        
    user_sentiment = {
        'ประชาธิปัตย์': {'pos': 0, 'neg': 0}, 
        'พลังประชารัฐ': {'pos': 0, 'neg': 0}, 
        'รวมพลังประชาชาติไทย': {'pos': 0, 'neg': 0}, 
        'เสรีรวมไทย': {'pos': 0, 'neg': 0}, 
        'เพื่อไทย': {'pos': 0, 'neg': 0}, 
        'อนาคตใหม่':{'pos': 0, 'neg': 0},
    }
    
    for datum in tweet_data:
        tweet = datum['text']
        
        if not any([party in tweet for party in party_name]):
            continue
        
        result = sentiment(tweet)
        for party in party_name:
            if party in tweet:
                user_sentiment[party][result] += 1

    user_sentiment_list.append(user_sentiment)

# %%
thd_list = []

for index in range(0, len(user_tweet_files)):    
    file = user_tweet_files[index]
    path_to_file = './user-tweet/%s' % file
    user = file.split('.')[0]
    
    with open(path_to_file, 'r', encoding='utf8') as fp:
        data = json.load(fp)
    fp.close()    
    
    thd = threading.Thread(target=sentiment_thread, args=(data,index))
    thd_list.append(thd)

for thd in thd_list:
    thd.start()
    thd.join()
    
print(len(user_sentiment_list))
# Out:
# Now, the index is 0
# Now, the index is 10
# Now, the index is 20
# Now, the index is 30
# Now, the index is 40
# Now, the index is 50
# Now, the index is 60
# Now, the index is 70
# Now, the index is 80
# Now, the index is 90
# Now, the index is 100
# Now, the index is 110
# Now, the index is 120
# Now, the index is 130
# Now, the index is 140
# Now, the index is 150
# Now, the index is 160
# Now, the index is 170
# Now, the index is 180
# Now, the index is 190
# Now, the index is 200
# Now, the index is 210
# Now, the index is 220
# Now, the index is 230
# Now, the index is 240
# Now, the index is 250
# Now, the index is 260
# Now, the index is 270
# Now, the index is 280
# Now, the index is 290
# Now, the index is 300
# Now, the index is 310
# Now, the index is 320
# Now, the index is 330
# Now, the index is 340
# Now, the index is 350
# Now, the index is 360
# Now, the index is 370
# Now, the index is 380
# Now, the index is 390
# Now, the index is 400
# Now, the index is 410
# Now, the index is 420
# Now, the index is 430
# Now, the index is 440
# Now, the index is 450
# Now, the index is 460
# Now, the index is 470
# Now, the index is 480
# Now, the index is 490
# Now, the index is 500
# Now, the index is 510
# Now, the index is 520
# Now, the index is 530
# Now, the index is 540
# Now, the index is 550
# Now, the index is 560
# Now, the index is 570
# Now, the index is 580
# Now, the index is 590
# Now, the index is 600
# Now, the index is 610
# Now, the index is 620
# Now, the index is 630
# Now, the index is 640
# Now, the index is 650
# Now, the index is 660
# Now, the index is 670
# Now, the index is 680
# Now, the index is 690
# Now, the index is 700
# Now, the index is 710
# Now, the index is 720
# Now, the index is 730
# Now, the index is 740
# Now, the index is 750
# Now, the index is 760
# Now, the index is 770
# Now, the index is 780
# Now, the index is 790
# Now, the index is 800
# Now, the index is 810
# Now, the index is 820
# Now, the index is 830
# Now, the index is 840
# Now, the index is 850
# Now, the index is 860
# Now, the index is 870
# Now, the index is 880
# Now, the index is 890
# Now, the index is 900
# Now, the index is 910
# Now, the index is 920
# Now, the index is 930
# Now, the index is 940
# Now, the index is 950
# Now, the index is 960
# Now, the index is 970
# Now, the index is 980
# Now, the index is 990
# Now, the index is 1000
# Now, the index is 1010
# Now, the index is 1020
# Now, the index is 1030
# Now, the index is 1040
# Now, the index is 1050
# Now, the index is 1060
# Now, the index is 1070
# Now, the index is 1080
# Now, the index is 1090
# Now, the index is 1100
# Now, the index is 1110
# Now, the index is 1120
# Now, the index is 1130
# Now, the index is 1140
# Now, the index is 1150
# Now, the index is 1160
# Now, the index is 1170
# Now, the index is 1180
# Now, the index is 1190
# Now, the index is 1200
# Now, the index is 1210
# Now, the index is 1220
# Now, the index is 1230
# Now, the index is 1240
# Now, the index is 1250
# Now, the index is 1260
# Now, the index is 1270
# Now, the index is 1280
# Now, the index is 1290
# Now, the index is 1300
# Now, the index is 1310
# Now, the index is 1320
# Now, the index is 1330
# Now, the index is 1340
# Now, the index is 1350
# Now, the index is 1360
# Now, the index is 1370
# Now, the index is 1380
# Now, the index is 1390
# Now, the index is 1400
# Now, the index is 1410
# Now, the index is 1420
# Now, the index is 1430
# Now, the index is 1440
# Now, the index is 1450
# Now, the index is 1460
# Now, the index is 1470
# Now, the index is 1480
# Now, the index is 1490
# Now, the index is 1500
# Now, the index is 1510
# Now, the index is 1520
# Now, the index is 1530
# Now, the index is 1540
# Now, the index is 1550
# Now, the index is 1560
# Now, the index is 1570
# Now, the index is 1580
# Now, the index is 1590
# Now, the index is 1600
# Now, the index is 1610
# Now, the index is 1620
# Now, the index is 1630
# Now, the index is 1640
# Now, the index is 1650
# Now, the index is 1660
# Now, the index is 1670
# Now, the index is 1680
# Now, the index is 1690
# Now, the index is 1700
# Now, the index is 1710
# Now, the index is 1720
# Now, the index is 1730
# Now, the index is 1740
# Now, the index is 1750
# Now, the index is 1760
# Now, the index is 1770
# Now, the index is 1780
# Now, the index is 1790
# Now, the index is 1800
# Now, the index is 1810
# Now, the index is 1820
# Now, the index is 1830
# Now, the index is 1840
# Now, the index is 1850
# Now, the index is 1860
# Now, the index is 1870
# Now, the index is 1880
# Now, the index is 1890
# Now, the index is 1900
# Now, the index is 1910
# Now, the index is 1920
# Now, the index is 1930
# Now, the index is 1940
# Now, the index is 1950
# Now, the index is 1960
# Now, the index is 1970
# Now, the index is 1980
# Now, the index is 1990
# Now, the index is 2000
# Now, the index is 2010
# Now, the index is 2020
# Now, the index is 2030
# Now, the index is 2040
# Now, the index is 2050
# Now, the index is 2060
# Now, the index is 2070
# Now, the index is 2080
# Now, the index is 2090
# Now, the index is 2100
# Now, the index is 2110
# Now, the index is 2120
# Now, the index is 2130
# Now, the index is 2140
# Now, the index is 2150
# Now, the index is 2160
# Now, the index is 2170
# Now, the index is 2180
# Now, the index is 2190
# Now, the index is 2200
# Now, the index is 2210
# Now, the index is 2220
# Now, the index is 2230
# Now, the index is 2240
# Now, the index is 2250
# Now, the index is 2260
# Now, the index is 2270
# Now, the index is 2280
# Now, the index is 2290
# Now, the index is 2300
# Now, the index is 2310
# Now, the index is 2320
# Now, the index is 2330
# Now, the index is 2340
# Now, the index is 2350
# Now, the index is 2360
# Now, the index is 2370
# Now, the index is 2380
# Now, the index is 2390
# Now, the index is 2400
# Now, the index is 2410
# Now, the index is 2420
# Now, the index is 2430
# Now, the index is 2440
# Now, the index is 2450
# Now, the index is 2460
# Now, the index is 2470
# Now, the index is 2480
# Now, the index is 2490
# Now, the index is 2500
# Now, the index is 2510
# Now, the index is 2520
# Now, the index is 2530
# Now, the index is 2540
# Now, the index is 2550
# Now, the index is 2560
# Now, the index is 2570
# Now, the index is 2580
# Now, the index is 2590
# Now, the index is 2600
# Now, the index is 2610
# Now, the index is 2620
# Now, the index is 2630
# Now, the index is 2640
# Now, the index is 2650
# Now, the index is 2660
# Now, the index is 2670
# Now, the index is 2680
# Now, the index is 2690
# Now, the index is 2700
# Now, the index is 2710
# Now, the index is 2720
# Now, the index is 2730
# Now, the index is 2740
# Now, the index is 2750
# Now, the index is 2760
# Now, the index is 2770
# Now, the index is 2780
# Now, the index is 2790
# Now, the index is 2800
# Now, the index is 2810
# Now, the index is 2820
# Now, the index is 2830
# Now, the index is 2840
# Now, the index is 2850
# Now, the index is 2860
# Now, the index is 2870
# Now, the index is 2880
# Now, the index is 2890
# Now, the index is 2900
# Now, the index is 2910
# Now, the index is 2920
# Now, the index is 2930
# Now, the index is 2940
# Now, the index is 2950
# Now, the index is 2960
# Now, the index is 2970
# Now, the index is 2980
# Now, the index is 2990
# Now, the index is 3000
# Now, the index is 3010
# Now, the index is 3020
# Now, the index is 3030
# Now, the index is 3040
# Now, the index is 3050
# Now, the index is 3060
# Now, the index is 3070
# Now, the index is 3080
# Now, the index is 3090
# Now, the index is 3100
# Now, the index is 3110
# Now, the index is 3120
# Now, the index is 3130
# Now, the index is 3140
# Now, the index is 3150
# Now, the index is 3160
# Now, the index is 3170
# Now, the index is 3180
# Now, the index is 3190
# Now, the index is 3200
# Now, the index is 3210
# Now, the index is 3220
# Now, the index is 3230
# Now, the index is 3240
# Now, the index is 3250
# Now, the index is 3260
# Now, the index is 3270
# Now, the index is 3280
# Now, the index is 3290
# Now, the index is 3300
# Now, the index is 3310
# Now, the index is 3320
# Now, the index is 3330
# Now, the index is 3340
# Now, the index is 3350
# Now, the index is 3360
# Now, the index is 3370
# Now, the index is 3380
# Now, the index is 3390
# Now, the index is 3400
# Now, the index is 3410
# Now, the index is 3420
# Now, the index is 3430
# Now, the index is 3440
# Now, the index is 3450
# Now, the index is 3460
# Now, the index is 3470
# Now, the index is 3480
# Now, the index is 3490
# Now, the index is 3500
# Now, the index is 3510
# Now, the index is 3520
# Now, the index is 3530
# Now, the index is 3540
# Now, the index is 3550
# Now, the index is 3560
# Now, the index is 3570
# Now, the index is 3580
# Now, the index is 3590
# Now, the index is 3600
# Now, the index is 3610
# Now, the index is 3620
# Now, the index is 3630
# Now, the index is 3640
# Now, the index is 3650
# Now, the index is 3660
# Now, the index is 3670
# Now, the index is 3680
# Now, the index is 3690
# Now, the index is 3700
# Now, the index is 3710
# Now, the index is 3720
# Now, the index is 3730
# Now, the index is 3740
# Now, the index is 3750
# Now, the index is 3760
# Now, the index is 3770
# Now, the index is 3780
# Now, the index is 3790
# Now, the index is 3800
# Now, the index is 3810
# Now, the index is 3820
# Now, the index is 3830
# Now, the index is 3840
# Now, the index is 3850
# Now, the index is 3860
# Now, the index is 3870
# Now, the index is 3880
# Now, the index is 3890
# Now, the index is 3900
# Now, the index is 3910
# Now, the index is 3920
# Now, the index is 3930
# Now, the index is 3940
# Now, the index is 3950
# Now, the index is 3960
# Now, the index is 3970
# Now, the index is 3980
# Now, the index is 3990
# Now, the index is 4000
# Now, the index is 4010
# Now, the index is 4020
# Now, the index is 4030
# Now, the index is 4040
# Now, the index is 4050
# Now, the index is 4060
# Now, the index is 4070
# Now, the index is 4080
# Now, the index is 4090
# Now, the index is 4100
# Now, the index is 4110
# Now, the index is 4120
# Now, the index is 4130
# Now, the index is 4140
# Now, the index is 4150
# Now, the index is 4160
# Now, the index is 4170
# Now, the index is 4180
# Now, the index is 4190
# Now, the index is 4200
# Now, the index is 4210
# Now, the index is 4220
# Now, the index is 4230
# Now, the index is 4240
# Now, the index is 4250
# Now, the index is 4260
# Now, the index is 4270
# Now, the index is 4280
# Now, the index is 4290
# Now, the index is 4300
# Now, the index is 4310
# Now, the index is 4320
# Now, the index is 4330
# Now, the index is 4340
# Now, the index is 4350
# Now, the index is 4360
# Now, the index is 4370
# Now, the index is 4380
# Now, the index is 4390
# Now, the index is 4400
# Now, the index is 4410
# Now, the index is 4420
# Now, the index is 4430
# Now, the index is 4440
# Now, the index is 4450
# Now, the index is 4460
# Now, the index is 4470
# Now, the index is 4480
# Now, the index is 4490
# Now, the index is 4500
# Now, the index is 4510
# Now, the index is 4520
# Now, the index is 4530
# Now, the index is 4540
# Now, the index is 4550
# Now, the index is 4560
# Now, the index is 4570
# Now, the index is 4580
# Now, the index is 4590
# Now, the index is 4600
# Now, the index is 4610
# Now, the index is 4620
# Now, the index is 4630
# Now, the index is 4640
# Now, the index is 4650
# Now, the index is 4660
# Now, the index is 4670
# 4672

# %%
no_zero_sentiment = list(
    filter(
        lambda x: any([x[key]['pos'] != 0 or x[key]['neg'] != 0 for key in party_name]), 
        user_sentiment_list
    )
)

# %%
pro_party = {
    'ประชาธิปัตย์': [], 
    'พลังประชารัฐ': [], 
    'รวมพลังประชาชาติไทย': [], 
    'เสรีรวมไทย': [], 
    'เพื่อไทย': [], 
    'อนาคตใหม่': [],
}

for i in range(len(no_zero_sentiment)):
    max_pos_list = [x['pos'] for x in no_zero_sentiment[i].values()]
    max_index = max_pos_list.index(max(max_pos_list)) if sum(max_pos_list) > 1 else None
    if max_index != None:
        max_pos_party = list(pro_party.keys())[max_index]
        pro_party[max_pos_party].append(no_zero_sentiment[i])
# Out:
# [{'ประชาธิปัตย์': {'neg': 0, 'pos': 0},
#   'พลังประชารัฐ': {'neg': 0, 'pos': 0},
#   'รวมพลังประชาชาติไทย': {'neg': 0, 'pos': 0},
#   'อนาคตใหม่': {'neg': 0, 'pos': 3},
#   'เพื่อไทย': {'neg': 0, 'pos': 0},
#   'เสรีรวมไทย': {'neg': 0, 'pos': 0}},
#  {'ประชาธิปัตย์': {'neg': 0, 'pos': 0},
#   'พลังประชารัฐ': {'neg': 0, 'pos': 0},
#   'รวมพลังประชาชาติไทย': {'neg': 0, 'pos': 0},
#   'อนาคตใหม่': {'neg': 0, 'pos': 2},
#   'เพื่อไทย': {'neg': 0, 'pos': 0},
#   'เสรีรวมไทย': {'neg': 0, 'pos': 0}}]

# %%
def sum_neg_pos(x, y):
    return {
        'neg': x['neg'] + y['neg'],
        'pos': x['pos'] + y['pos']
    }

def sum_sentiment_dict(x, y):
    return {
        'ประชาธิปัตย์': sum_neg_pos(x['ประชาธิปัตย์'], y['ประชาธิปัตย์']),
        'พลังประชารัฐ': sum_neg_pos(x['พลังประชารัฐ'], y['พลังประชารัฐ']),
        'รวมพลังประชาชาติไทย': sum_neg_pos(x['รวมพลังประชาชาติไทย'], y['รวมพลังประชาชาติไทย']),
        'อนาคตใหม่': sum_neg_pos(x['อนาคตใหม่'], y['อนาคตใหม่']),
        'เพื่อไทย': sum_neg_pos(x['เพื่อไทย'], y['เพื่อไทย']),
        'เสรีรวมไทย': sum_neg_pos(x['เสรีรวมไทย'], y['เสรีรวมไทย'])
    }

sum_sentiment = {}
for party in pro_party:
    sum_sentiment['pro-'+party] = dict(reduce(sum_sentiment_dict, pro_party[party]))

# %%
def plot_sentiment(party):
    party_sum_sentiment = sum_sentiment['pro-%s' % party]
    df = pd.DataFrame(party_sum_sentiment).transpose()

    matplotlib.rc('font', family='TH Sarabun New', size=16)

    percent = lambda x,y: x/sum(y)*100

    neg_arr = [i[0] / sum(i) * 100 for i in df.values]
    pos_arr = [i[1] / sum(i) * 100 for i in df.values]

    encoded_name = [i for i in party_sum_sentiment.keys()]

    idx = range(len(encoded_name))
    
    plt.figure(figsize=(8, 5))
    
    plt1 = plt.bar(encoded_name, pos_arr, align='center', color='#9ED53C', width=0.4)
    plt2 = plt.bar(encoded_name, neg_arr, align='center', bottom=pos_arr, color='#E54941', width=0.4)
    
    plt.xticks(rotation=45)
    plt.yticks(range(0, 101, 10))
    plt.title('ปฏิกิริยาต่อพรรคอื่น ๆ ของกลุ่มบุคคล\nที่ทวิตเนื้อหาไปทางบวกเป็นหลักกับพรรค "%s"' % party)
    plt.legend((plt1, plt2), ('Positive', 'Negative'))
    
    plt.savefig(party + '.jpg')
    plt.show()

for party in party_name:
    plot_sentiment(party)
